# %%
str ="hello ml enthusiast people this is our first class"
new_str =str.split()
for x in new_str:
   print(x)
# Out:
# hello
# ml
# enthusiast
# people
# this
# is
# our
# first
# class

# %%
number=[24,43,21,66,33]
max_number = number[0]
second_max_number=number[1]
for x in range(1,5):
  if number[x]>max_number:
    second_max_number=max_number
    max_number=number[x]
print(second_max_number)
# Out:
# 43
